# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!chmod +x "/content/drive/MyDrive/Colab Notebooks/assignment4_materials/assignment4_materials/download_language.sh"
#!"/content/drive/MyDrive/Colab Notebooks/assignment4_materials/assignment4_materials/download_language.sh"

# %%
import sys
#sys.path.insert(0,"/CS498DL/assignment4_materials/assignment4_materials/gan")
sys.path.insert(0,"/content/drive/MyDrive/Colab Notebooks/assignment4_materials/assignment4_materials")

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (1.2.0)

# %%
import os
import time
import math
import glob
import string
import random 

import torch
import torch.nn as nn

from rnn.helpers import time_since

# %matplotlib inline

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
!"download_language.sh"
# Out:
# /bin/bash: download_language.sh: command not found

# %% [markdown]
# # Language recognition with an RNN
#
# If you've ever used an online translator you've probably seen a feature that automatically detects the input language. While this might be easy to do if you input unicode characters that are unique to one or a small group of languages (like "你好" or "γεια σας"), this problem is more challenging if the input only uses the available ASCII characters. In this case, something like "těší mě" would beome "tesi me" in the ascii form. This is a more challenging problem in which the language must be recognized purely by the pattern of characters rather than unique unicode characters.
#
# We will train an RNN to solve this problem for a small set of languages thta can be converted to romanized ASCII form. For training data it would be ideal to have a large and varied dataset in different language styles. However, it is easy to find copies of the Bible which is a large text translated to different languages but in the same easily parsable format, so we will use 20 different copies of the Bible as training data. Using the same book for all of the different languages will hopefully prevent minor overfitting that might arise if we used different books for each language (fitting to common characteristics of the individual books rather than the language).

# %%
from unidecode import unidecode as unicodeToAscii

all_characters = string.printable
n_letters = len(all_characters)

print(unicodeToAscii('těší mě'))
# Out:
# tesi me

# %%
# Read a file and split into lines
def readFile(filename):
    data = open(filename, encoding='utf-8').read().strip()
    return unicodeToAscii(data)

def get_category_data(data_path):
    # Build the category_data dictionary, a list of names per language
    category_data = {}
    all_categories = []
    for filename in glob.glob(data_path):
        category = os.path.splitext(os.path.basename(filename))[0].split('_')[0]
        all_categories.append(category)
        data = readFile(filename)
        category_data[category] = data
    
    return category_data, all_categories

# %% [markdown]
# The original text is split into two parts, train and test, so that we can make sure that the model is not simply memorizing the train data.

# %%
train_data_path = 'language_data/train/*_train.txt'
test_data_path = 'language_data/test/*_test.txt'

train_category_data, all_categories = get_category_data(train_data_path)
test_category_data, test_all_categories = get_category_data(test_data_path)

n_languages = len(all_categories)

print(len(all_categories))
print(all_categories)
# Out:
# 20
# ['danish', 'turkish', 'vietnamese', 'finnish', 'lithuanian', 'maori', 'albanian', 'romanian', 'esperanto', 'french', 'xhosa', 'czech', 'norwegian', 'english', 'swedish', 'hungarian', 'spanish', 'german', 'portuguese', 'italian']

# %% [markdown]
# # Data processing

# %%
def categoryFromOutput(output):
    top_n, top_i = output.topk(1)
    category_i = top_i[:, 0]
    return category_i

# Turn string into long tensor
def stringToTensor(string):
    tensor = torch.zeros(len(string), requires_grad=True).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return tensor

def load_random_batch(text, chunk_len, batch_size):
    input_data = torch.zeros(batch_size, chunk_len).long().to(device)
    target = torch.zeros(batch_size, 1).long().to(device)
    input_text = []
    for i in range(batch_size):
        category = all_categories[random.randint(0, len(all_categories) - 1)]
        line_start = random.randint(0, len(text[category])-chunk_len)
        category_tensor = torch.tensor([all_categories.index(category)], dtype=torch.long)
        line = text[category][line_start:line_start+chunk_len]
        input_text.append(line)
        input_data[i] = stringToTensor(line)
        target[i] = category_tensor
    return input_data, target, input_text

# %% [markdown]
# Implement Model
# ====================
#
# For this classification task, we can use the same model we implement for the generation task which is located in `rnn/model.py`. See the `MP4_P2_generation.ipynb` notebook for more instructions. In this case each output vector of our RNN will have the dimension of the number of possible languages (i.e. `n_languages`). We will use this vector to predict a distribution over the languages.
#
# In the generation task, we used the output of the RNN at every time step to predict the next letter and our loss included the output from each of these predictions. However, in this task we use the output of the RNN at the end of the sequence to predict the language, so our loss function will use only the predicted output from the last time step.

# %% [markdown]
# # Train RNN

# %%
from rnn.model import RNN

# %%
chunk_len = 50

BATCH_SIZE = 128
n_epochs = 1000
hidden_size = 100
n_layers = 1
learning_rate = 0.0005
model_type = 'gru'

criterion = nn.CrossEntropyLoss()

torch.manual_seed(16393350299325223735)
rnn = RNN(n_letters, hidden_size, n_languages, model_type=model_type, n_layers=n_layers).to(device)

# %% [markdown]
# **TODO:** Fill in the train function. You should initialize a hidden layer representation using your RNN's `init_hidden` function, set the model gradients to zero, and loop over each time step (character) in the input tensor. For each time step compute the output of the of the RNN and the next hidden layer representation. The cross entropy loss should be computed over the last RNN output scores from the end of the sequence and the target classification tensor. Lastly, call backward on the loss and take an optimizer step.

# %%
def train(rnn, target_tensor, data_tensor, optimizer, criterion, batch_size=BATCH_SIZE):
    """
    Inputs:
    - rnn: model
    - target_target: target character data tensor of shape (batch_size, 1)
    - data_tensor: input character data tensor of shape (batch_size, chunk_len)
    - optimizer: rnn model optimizer
    - criterion: loss function
    - batch_size: data batch size
    
    Returns:
    - output: output from RNN from end of sequence 
    - loss: computed loss value as python float
    
    """
    
    output, loss = None, None
    
    ####################################
    #          YOUR CODE HERE          #
    ####################################
    h = rnn.init_hidden(batch_size, device)
    rnn.zero_grad()
    for c in range(chunk_len):
        char = data_tensor[:, c]
        output, h = rnn.forward(char, h)
        
    loss = criterion(output, target_tensor.squeeze())
    loss.backward()
    optimizer.step()

    ##########       END      ##########

    return output, loss

# %%
def evaluate(rnn, data_tensor, seq_len=chunk_len, batch_size=BATCH_SIZE):
    with torch.no_grad():
        data_tensor = data_tensor.to(device)
        hidden = rnn.init_hidden(batch_size, device=device)
        for i in range(seq_len):
            output, hidden = rnn(data_tensor[:,i], hidden)
        
        return output
    
def eval_test(rnn, category_tensor, data_tensor):
    with torch.no_grad():
        output = evaluate(rnn, data_tensor)
        loss = criterion(output, category_tensor.squeeze())
        return output, loss.item()

# %%
n_iters = 100000 #2000 #100000
print_every = 50
plot_every = 50


# Keep track of losses for plotting
current_loss = 0
current_test_loss = 0
all_losses = []
all_test_losses = []

start = time.time()

optimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.1)

number_correct = 0
for iter in range(1, n_iters + 1):
    input_data, target_category, text_data = load_random_batch(train_category_data, chunk_len, BATCH_SIZE)
    output, loss = train(rnn, target_category, input_data, optimizer, criterion)
    current_loss += loss
    
    _, test_loss = eval_test(rnn, target_category, input_data)
    current_test_loss += test_loss
    
    guess_i = categoryFromOutput(output)
    number_correct += (target_category.squeeze()==guess_i.squeeze()).long().sum()
    
    # Print iter number, loss, name and guess
    if iter % print_every == 0:
        sample_idx = 0
        guess = all_categories[guess_i[sample_idx]]
        
        category = all_categories[int(target_category[sample_idx])]
        
        correct = '✓' if guess == category else '✗ (%s)' % category
        print('%d %d%% (%s) %.4f %.4f %s / %s %s' % (iter, iter / n_iters * 100, time_since(start), loss, test_loss, text_data[sample_idx], guess, correct))
        print('Train accuracy: {}'.format(float(number_correct)/float(print_every*BATCH_SIZE)))
        number_correct = 0
    
    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0
        all_test_losses.append(current_test_loss / plot_every)
        current_test_loss = 0
# Out:
# 50 0% (0m 3s) 0.0157 0.0135 nel traite Jonathan avec la derniere rigueur! Que  / french ✓
# Train accuracy: 0.9934375
# 100 0% (0m 6s) 0.0501 0.0450 inesli pred krale a Jojadu stribro, jez zustalo. T / czech ✓
# Train accuracy: 0.99265625
# 150 0% (0m 9s) 0.0052 0.0049 ia; nao negara bem algum aos que andam na retidao. / portuguese ✓
# Train accuracy: 0.9953125
# 200 0% (0m 12s) 0.0097 0.0093 nga sopraffatto". Or Gionathan e Ahimaats stavano  / italian ✓
# Train accuracy: 0.9934375
# 250 0% (0m 15s) 0.0976 0.0869 leva ao porto desejado. Deem gracas ao Senhor pela / portuguese ✓
# Train accuracy: 0.99203125
# 300 0% (0m 18s) 0.0226 0.0204 te haben ihnen auch Geld und Korn geliehen. Wir wo / german ✓
# Train accuracy: 0.9921875
# 350 0% (0m 21s) 0.0496 0.0463 le, Hanania, Mishael e Azaria; e questi furono amm / italian ✓
# Train accuracy: 0.99296875
# 400 0% (0m 24s) 0.0029 0.0025  han ikke ser noget, og pa himmelens hvelving vand / norwegian ✓
# Train accuracy: 0.9928125
# 450 0% (0m 27s) 0.0044 0.0038 ana e ia a Paraama tama a Peoro, hei kanga mo kout / maori ✓
# Train accuracy: 0.9946875
# 500 0% (0m 30s) 0.0337 0.0285 i. Musu sirdies dziaugsmas dingo, zaidimai virto l / lithuanian ✓
# Train accuracy: 0.99328125
# 550 0% (0m 33s) 0.0131 0.0113 tos, cxar ni vidis Dion. Sed lia edzino diris al l / esperanto ✓
# Train accuracy: 0.9925
# 600 0% (0m 36s) 0.0084 0.0074 a okulungileyo. Ekubulalekeni konke kubakho ungeni / xhosa ✓
# Train accuracy: 0.9953125
# 650 0% (0m 39s) 0.0157 0.0130 d the screen for the gate of the court, the cords  / english ✓
# Train accuracy: 0.99359375
# 700 0% (0m 42s) 0.0259 0.0211 rase. Con peligro de nuestras vidas traiamos nuest / spanish ✓
# Train accuracy: 0.9934375
# 750 0% (0m 45s) 0.0014 0.0013 hall say: for the Holy Spirit shall teach you in t / english ✓
# Train accuracy: 0.99140625
# 800 0% (0m 48s) 0.0195 0.0141 oke. Atehere Davidi i tha Ornanit: "Me jep siperfa / albanian ✓
# Train accuracy: 0.99484375
# 850 0% (0m 51s) 0.0169 0.0128 nge et argammelt Lam som Skyldoffer; den forlobne  / danish ✓
# Train accuracy: 0.99265625
# 900 0% (0m 54s) 0.0306 0.0260 athiso sayo esiphezu kwayo, nokuphololoza komlomo  / xhosa ✓
# Train accuracy: 0.99390625
# 950 0% (0m 57s) 0.0175 0.0151 eg sa ved Floden Kebar. Nar Keruberne gik, gik ogs / danish ✓
# Train accuracy: 0.99421875
# 1000 1% (1m 0s) 0.0123 0.0108 disindise ngokwenceba yakho; Bazi ukuba sisandla s / xhosa ✓
# Train accuracy: 0.9928125
# 1050 1% (1m 3s) 0.0104 0.0085 , infanoj, la instruon de la patro,   Kaj atentu,  / esperanto ✓
# Train accuracy: 0.9925
# 1100 1% (1m 6s) 0.0146 0.0129 ari. A budu stihat zlobu sveta a nepravost svevoln / czech ✓
# Train accuracy: 0.995
# 1150 1% (1m 9s) 0.0187 0.0175 rapunsi de lovituri pe ulitele Babilonului! Caci I / romanian ✓
# Train accuracy: 0.9921875
# 1200 1% (1m 12s) 0.0149 0.0106 p mot sin moder, sonhustrun mot sin svarmoder, och / swedish ✓
# Train accuracy: 0.990625
# 1250 1% (1m 15s) 0.0910 0.0796  will rise up as in mount Perazim, he will be wrot / english ✓
# Train accuracy: 0.9915625
# 1300 1% (1m 18s) 0.0045 0.0041 ingossa, auta minut siita. Mita mina puhun hanelle / finnish ✓
# Train accuracy: 0.99484375
# 1350 1% (1m 21s) 0.0099 0.0078 i ar duonos kasni ir prasys, kad paskirtu juos kun / lithuanian ✓
# Train accuracy: 0.9928125
# 1400 1% (1m 24s) 0.1040 0.0871 r soll verschlossen bleiben und nicht aufgetan wer / german ✓
# Train accuracy: 0.9934375
# 1450 1% (1m 27s) 0.0282 0.0222 han; me teper se Hemani, se Kakoli dhe se Darda, b / albanian ✓
# Train accuracy: 0.99234375
# 1500 1% (1m 30s) 0.0017 0.0017 budete ridit mymi narizenimi, zachovavat moje rady / czech ✓
# Train accuracy: 0.99203125
# 1550 1% (1m 33s) 0.0044 0.0037  ennusmerkkeja. Han pudistaa nuoliaan ja kysyy jum / finnish ✓
# Train accuracy: 0.99328125
# 1600 1% (1m 36s) 0.0085 0.0075  miei occhi, i miei occhi si struggono in lacrime, / italian ✓
# Train accuracy: 0.99390625
# 1650 1% (1m 39s) 0.0243 0.0213 . Et Osee, fils d'Ela, fit une conspiration contre / french ✓
# Train accuracy: 0.995
# 1700 1% (1m 42s) 0.0166 0.0159  skolen vara mitt folk och jag skall vara eder Gud / swedish ✓
# Train accuracy: 0.99390625
# 1750 1% (1m 45s) 0.0261 0.0244 eget land og til min slekt og hente en hustru til  / norwegian ✓
# Train accuracy: 0.991875
# 1800 1% (1m 48s) 0.0339 0.0293  cxe mangxo kun la dek du discxiploj; kaj dum ili  / esperanto ✓
# Train accuracy: 0.99328125
# 1850 1% (1m 51s) 0.0011 0.0010 pandero il mio spirito sulla tua progenie, e la mi / italian ✓
# Train accuracy: 0.995625
# 1900 1% (1m 55s) 0.0035 0.0033 ewayini entsha, nezeoli, koovimba. Ndamisa phezu k / xhosa ✓
# Train accuracy: 0.99390625
# 1950 1% (1m 58s) 0.0216 0.0160 nde disension, el tribuno, teniendo temor de que P / spanish ✓
# Train accuracy: 0.99515625
# 2000 2% (2m 1s) 0.0172 0.0141 maistui". Ir taip ivyko. Dievas mate visa, ka buvo / lithuanian ✓
# Train accuracy: 0.99421875
# 2050 2% (2m 4s) 0.0077 0.0064 s, kaj vi savos niajn animojn kontraux morto. Kaj  / esperanto ✓
# Train accuracy: 0.9946875
# 2100 2% (2m 7s) 0.0105 0.0094  mezzo a loro a presentarsi davanti all'Eterno. E  / italian ✓
# Train accuracy: 0.9934375
# 2150 2% (2m 10s) 0.0040 0.0039 l varovat, a ty jsi svou dusi vysvobodil." I spoci / czech ✓
# Train accuracy: 0.99359375
# 2200 2% (2m 13s) 0.0401 0.0058 tvi pred Vodni branou a vyzvali znalce Zakona Ezdr / czech ✓
# Train accuracy: 0.99546875
# 2250 2% (2m 16s) 0.0148 0.0109 ua o ben nay song Gio-danh, hoac o trong nui, duoi / vietnamese ✓
# Train accuracy: 0.99328125
# 2300 2% (2m 19s) 0.0047 0.0035 gi. Na kua rite mai i a Ihowa tetahi ika nui hei h / maori ✓
# Train accuracy: 0.9921875
# 2350 2% (2m 22s) 0.0210 0.0160 diracagim. Ancak, kendisine buyurmadigim bir sozu  / turkish ✓
# Train accuracy: 0.993125
# 2400 2% (2m 25s) 0.0435 0.0298 chete-la; a cause de mes ennemis, delivre-moi! Toi / french ✓
# Train accuracy: 0.9928125
# 2450 2% (2m 28s) 0.0284 0.0246 turincios paveldejimo teise, privalo teketi uz tos / lithuanian ✓
# Train accuracy: 0.9940625
# 2500 2% (2m 31s) 0.0164 0.0134 sitt ore til, sa den ikke horer pa slangetemmernes / norwegian ✓
# Train accuracy: 0.99359375
# 2550 2% (2m 34s) 0.0713 0.0550 ing. And Jehovah uttereth his voice before his arm / english ✓
# Train accuracy: 0.9946875
# 2600 2% (2m 37s) 0.0772 0.0554 sine dokunmadik. Benden once gorev yapan valiler h / turkish ✓
# Train accuracy: 0.9953125
# 2650 2% (2m 40s) 0.0754 0.0597 aKoniyahu unyana kaYehoyakim,  owenziwa ukumkani e / xhosa ✓
# Train accuracy: 0.99328125
# 2700 2% (2m 43s) 0.0035 0.0033 uunnelleet hanta. Silloin Herra lahetti heidan kim / finnish ✓
# Train accuracy: 0.99390625
# 2750 2% (2m 46s) 0.0276 0.0103  Con chau Me-ra-ri con sot lai boi chi phai Sa-bu- / vietnamese ✓
# Train accuracy: 0.9928125
# 2800 2% (2m 49s) 0.0302 0.0247 Esau a ridicat glasul si a plins. Tatal sau Isaac  / romanian ✓
# Train accuracy: 0.9921875
# 2850 2% (2m 52s) 0.0350 0.0241  (Catre mai marele cintaretilor. Un psalm al lui D / romanian ✓
# Train accuracy: 0.9940625
# 2900 2% (2m 55s) 0.0040 0.0035 querie, des deserts eternels. Et je ferai cesser p / french ✓
# Train accuracy: 0.995
# 2950 2% (2m 58s) 0.0193 0.0165 ay ke, mot hinh cay ke o giua hai che-ru-bin; moi  / vietnamese ✓
# Train accuracy: 0.99390625
# 3000 3% (3m 1s) 0.0169 0.0137 urerai en vous. Comme le sarment ne peut porter du / french ✓
# Train accuracy: 0.99296875
# 3050 3% (3m 4s) 0.0242 0.0138  lanele ziisabatha zalo; ngayo yonke imihla yokuba / xhosa ✓
# Train accuracy: 0.99265625
# 3100 3% (3m 7s) 0.0259 0.0194 a tobe sve slovo, ktere jsem dal tvemu otci Davido / czech ✓
# Train accuracy: 0.9934375
# 3150 3% (3m 10s) 0.0349 0.0175 ck och ihalig. Och ovanpa den var ett pelarhuvud a / swedish ✓
# Train accuracy: 0.9940625
# 3200 3% (3m 13s) 0.0076 0.0064 tii ziceau ca a inviat vreun prooroc din cei din v / romanian ✓
# Train accuracy: 0.9934375
# 3250 3% (3m 16s) 0.0034 0.0032 ganui o Ihowa, o koutou, i taua wa, hei whakapuaki / maori ✓
# Train accuracy: 0.99296875
# 3300 3% (3m 19s) 0.0569 0.0354 n avec les betes des champs, jusqu'a ce que sept t / french ✓
# Train accuracy: 0.99203125
# 3350 3% (3m 22s) 0.0304 0.0171 d Reiter hat er ins Meer gesturzt! Der HERR ist me / german ✓
# Train accuracy: 0.9940625
# 3400 3% (3m 25s) 0.0117 0.0100 re Frymes se Shenjte dhe neve qe te mos ju ngarkoj / albanian ✓
# Train accuracy: 0.9934375
# 3450 3% (3m 28s) 0.0340 0.0280 aljas sonn, og byens hovedsmann Ma'aseja og histor / norwegian ✓
# Train accuracy: 0.99265625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-0bdeea9b29b1> in <module>()
#      21     current_loss += loss
#      22
# ---> 23     _, test_loss = eval_test(rnn, target_category, input_data)
#      24     current_test_loss += test_loss
#      25
#
# <ipython-input-15-09419602d561> in eval_test(rnn, category_tensor, data_tensor)
#      10 def eval_test(rnn, category_tensor, data_tensor):
#      11     with torch.no_grad():
# ---> 12         output = evaluate(rnn, data_tensor)
#      13         loss = criterion(output, category_tensor.squeeze())
#      14         return output, loss.item()
#
# <ipython-input-15-09419602d561> in evaluate(rnn, data_tensor, seq_len, batch_size)
#       4         hidden = rnn.init_hidden(batch_size, device=device)
#       5         for i in range(seq_len):
# ----> 6             output, hidden = rnn(data_tensor[:,i], hidden)
#       7
#       8         return output
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /content/drive/MyDrive/Colab Notebooks/assignment4_materials/assignment4_materials/rnn/model.py in forward(self, input, hidden)
#      75
#      76         output = output.reshape(input.size(0), -1)
# ---> 77         output = self.linear(output)
#      78         return output, hidden
#      79
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     934     def __getattr__(self, name: str) -> Union[Tensor, 'Module']:
#     935         if '_parameters' in self.__dict__:
# --> 936             _parameters = self.__dict__['_parameters']
#     937             if name in _parameters:
#     938                 return _parameters[name]
#
# KeyboardInterrupt:

# %%
torch.seed()
# Out:
# 763570479187877985

# %% [markdown]
# Plot loss functions
# --------------------

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_losses, color='b')
plt.plot(all_test_losses, color='r')

# %% [markdown]
# Evaluate results
# -------------------
#
# We now vizualize the performance of our model by creating a confusion matrix. The ground truth languages of samples are represented by rows in the matrix while the predicted languages are represented by columns.
#
# In this evaluation we consider sequences of variable sizes rather than the fixed length sequences we used for training.

# %%
eval_batch_size = 1  # needs to be set to 1 for evaluating different sequence lengths

# Keep track of correct guesses in a confusion matrix
confusion = torch.zeros(n_languages, n_languages)
n_confusion = 1000
num_correct = 0
total = 0

for i in range(n_confusion):
    eval_chunk_len = random.randint(10, 50) # in evaluation we will look at sequences of variable sizes
    input_data, target_category, text_data = load_random_batch(test_category_data, chunk_len=eval_chunk_len, batch_size=eval_batch_size)
    output = evaluate(rnn, input_data, seq_len=eval_chunk_len, batch_size=eval_batch_size)
    
    guess_i = categoryFromOutput(output)
    category_i = [int(target_category[idx]) for idx in range(len(target_category))]
    for j in range(eval_batch_size):
        category = all_categories[category_i[j]] 
        confusion[category_i[j]][guess_i[j]] += 1
        num_correct += int(guess_i[j]==category_i[j])
        total += 1

print('Test accuracy: ', float(num_correct)/float(n_confusion*eval_batch_size))

# Normalize by dividing every row by its sum
for i in range(n_languages):
    confusion[i] = confusion[i] / confusion[i].sum()

# Set up plot
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(confusion.numpy())
fig.colorbar(cax)

# Set up axes
ax.set_xticklabels([''] + all_categories, rotation=90)
ax.set_yticklabels([''] + all_categories)

# Force label at every tick
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()
# Out:
# Test accuracy:  0.919

# %% [markdown]
# You can pick out bright spots off the main axis that show which
# languages it guesses incorrectly.

# %% [markdown]
# Run on User Input
# ---------------------
#
# Now you can test your model on your own input.

# %%
def predict(input_line, n_predictions=5):
    print('\n> %s' % input_line)
    with torch.no_grad():
        input_data = stringToTensor(input_line).long().unsqueeze(0).to(device)
        output = evaluate(rnn, input_data, seq_len=len(input_line), batch_size=1)

    # Get top N categories
    topv, topi = output.topk(n_predictions, dim=1)
    predictions = []

    for i in range(n_predictions):
        topv.shape
        topi.shape
        value = topv[0][i].item()
        category_index = topi[0][i].item()
        print('(%.2f) %s' % (value, all_categories[category_index]))
        predictions.append([value, all_categories[category_index]])

predict('This is a phrase to test the model on user input')
# Out:
# > This is a phrase to test the model on user input
# (6.27) english
# (5.23) albanian
# (2.93) french
# (1.68) norwegian
# (1.58) maori

# %% [markdown]
# # Output Kaggle submission file
#
# Once you have found a good set of hyperparameters submit the output of your model on the Kaggle test file.

# %%
### DO NOT CHANGE KAGGLE SUBMISSION CODE ####
import csv

kaggle_test_file_path = 'language_data/kaggle_rnn_language_classification_test.txt'
with open(kaggle_test_file_path, 'r') as f:
    lines = f.readlines()

output_rows = []
for i, line in enumerate(lines):
    sample = line.rstrip()
    sample_chunk_len = len(sample)
    input_data = stringToTensor(sample).unsqueeze(0)
    output = evaluate(rnn, input_data, seq_len=sample_chunk_len, batch_size=1)
    guess_i = categoryFromOutput(output)
    output_rows.append((str(i+1), all_categories[guess_i]))

submission_file_path = 'kaggle_rnn_submission.txt'
with open(submission_file_path, 'w') as f:
    output_rows = [('id', 'category')] + output_rows
    writer = csv.writer(f)
    writer.writerows(output_rows)
